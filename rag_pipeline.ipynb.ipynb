# %%
import sys
import numpy as np
import pandas as pd
import sklearn
import scipy
import torch

print("Python       :", sys.version)
print("NumPy        :", np.__version__)
print("Pandas       :", pd.__version__)
print("Scikit-learn :", sklearn.__version__)
print("SciPy        :", scipy.__version__)
print("PyTorch      :", torch.__version__)

print("\nCUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python       : 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# NumPy        : 2.0.2
# Pandas       : 2.3.3
# Scikit-learn : 1.6.1
# SciPy        : 1.16.3
# PyTorch      : 2.10.0+cu128
#
# CUDA available: True
# GPU: Tesla T4

# %%
# !pip install -q sentence-transformers datasets

# %%
import torch
import transformers
import sentence_transformers
import datasets

from sentence_transformers import SentenceTransformer
from datasets import load_dataset

print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
print("Sentence Transformers:", sentence_transformers.__version__)
print("Datasets:", datasets.__version__)

print("\nAll RAG libraries imported successfully.")
# Out:
# PyTorch: 2.10.0+cu128
# Transformers: 5.0.0
# Sentence Transformers: 5.4.1
# Datasets: 5.0.0
#
# All RAG libraries imported successfully.

# %%
from datasets import load_dataset

dataset = load_dataset(
    "bitext/Bitext-customer-support-llm-chatbot-training-dataset"
)

dataset
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# Bitext_Sample_Customer_Support_Training_(…):   0%|          | 0.00/19.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/26872 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['flags', 'instruction', 'category', 'intent', 'response'],
#         num_rows: 26872
#     })
# })

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np

# Load the original dataset
dataset = load_dataset(
    "bitext/Bitext-customer-support-llm-chatbot-training-dataset"
)

# Convert train split to DataFrame
df = dataset["train"].to_pandas()

print("Dataset loaded successfully.")
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isnull().sum())

print("\nFirst 5 examples:")
display(df.head())
# Out:
# Dataset loaded successfully.
# Shape: (26872, 5)
#
# Columns:
# ['flags', 'instruction', 'category', 'intent', 'response']
#
# Missing values:
# flags          0
# instruction    0
# category       0
# intent         0
# response       0
# dtype: int64
#
# First 5 examples:
#    flags                                        instruction category  \
# 0      B   question about cancelling order {{Order Number}}    ORDER
# 1    BQZ  i have a question about cancelling oorder {{Or...    ORDER
# 2   BLQZ    i need help cancelling puchase {{Order Number}}    ORDER
# 3     BL         I need to cancel purchase {{Order Number}}    ORDER
# 4  BCELN  I cannot afford this order, cancel purchase {{...    ORDER
#
#          intent                                           response
# 0  cancel_order  I've understood you have a question regarding ...
# 1  cancel_order  I've been informed that you have a question ab...
# 2  cancel_order  I can sense that you're seeking assistance wit...
# 3  cancel_order  I understood that you need assistance with can...
# 4  cancel_order  I'm sensitive to the fact that you're facing f...

# %%
# Remove duplicate customer instructions

original_rows = len(df)
unique_instructions = df["instruction"].nunique()

rag_df = (
    df[
        ["instruction", "category", "intent", "response"]
    ]
    .drop_duplicates(
        subset=["instruction"],
        keep="first"
    )
    .reset_index(drop=True)
)

print("Original rows      :", original_rows)
print("Unique instructions:", unique_instructions)
print("Removed duplicates :", original_rows - len(rag_df))
print("Final RAG dataset  :", len(rag_df))

print("\nUnique intent count:", rag_df["intent"].nunique())
# Out:
# Original rows      : 26872
# Unique instructions: 24635
# Removed duplicates : 2237
# Final RAG dataset  : 24635
#
# Unique intent count: 27

# %%
from sklearn.model_selection import train_test_split

# Split the deduplicated RAG dataset
rag_train_df, rag_eval_df = train_test_split(
    rag_df,
    test_size=0.20,
    random_state=42,
    stratify=rag_df["intent"]
)

# Reset indices
rag_train_df = rag_train_df.reset_index(drop=True)
rag_eval_df = rag_eval_df.reset_index(drop=True)

print("RAG train samples:", len(rag_train_df))
print("RAG evaluation samples:", len(rag_eval_df))

print("\nTrain intent distribution:")
print(rag_train_df["intent"].value_counts().sort_index())

print("\nEvaluation intent distribution:")
print(rag_eval_df["intent"].value_counts().sort_index())
# Out:
# RAG train samples: 19708
# RAG evaluation samples: 4927
#
# Train intent distribution:
# intent
# cancel_order                394
# change_order                696
# change_shipping_address     778
# check_cancellation_fee      760
# check_invoice               737
# check_payment_methods       799
# check_refund_policy         798
# complaint                   800
# contact_customer_service    800
# contact_human_agent         799
# create_account              714
# delete_account              734
# delivery_options            528
# delivery_period             799
# edit_account                622
# get_invoice                 727
# get_refund                  734
# newsletter_subscription     799
# payment_issue               799
# place_order                 798
# recover_password            796
# registration_problems       799
# review                      798
# set_up_shipping_address     798
# switch_account              690
# track_order                 646
# track_refund                566
# Name: count, dtype: int64
#
# Evaluation intent distribution:
# intent
# cancel_order                 99
# change_order                174
# change_shipping_address     195
# check_cancellation_fee      190
# check_invoice               184
# check_payment_methods       200
# check_refund_policy         199
# complaint                   200
# contact_customer_service    200
# contact_human_agent         200
# create_account              178
# delete_account              184
# delivery_options            132
# delivery_period             200
# edit_account                155
# get_invoice                 182
# get_refund                  184
# newsletter_subscription     200
# payment_issue               200
# place_order                 200
# recover_password            199
# registration_problems       200
# review                      199
# set_up_shipping_address     199
# switch_account              172
# track_order                 161
# track_refund                141
# Name: count, dtype: int64

# %%
# Final data leakage check

train_instructions = set(rag_train_df["instruction"])
eval_instructions = set(rag_eval_df["instruction"])

overlap = train_instructions.intersection(eval_instructions)

print("Data Leakage Check")
print("=" * 60)
print("RAG train samples :", len(rag_train_df))
print("RAG eval samples  :", len(rag_eval_df))

print("\nUnique train instructions:", len(train_instructions))
print("Unique eval instructions :", len(eval_instructions))

print("\nExact overlapping instructions:", len(overlap))

leakage_rate = len(overlap) / len(eval_instructions) * 100

print("Leakage rate:", f"{leakage_rate:.4f}%")

if len(overlap) == 0:
    print("\nPASS: No exact instruction leakage detected.")
else:
    print("\nWARNING: Exact instruction overlap detected.")
    print("\nExamples of overlapping instructions:")
    
    for instruction in list(overlap)[:10]:
        print("-", instruction)
# Out:
# Data Leakage Check
# ============================================================
# RAG train samples : 19708
# RAG eval samples  : 4927
#
# Unique train instructions: 19708
# Unique eval instructions : 4927
#
# Exact overlapping instructions: 0
# Leakage rate: 0.0000%
#
# PASS: No exact instruction leakage detected.

# %%
import torch
from sentence_transformers import SentenceTransformer

EMBEDDING_MODEL_NAME = "all-MiniLM-L6-v2"

embedding_model = SentenceTransformer(
    EMBEDDING_MODEL_NAME,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

print("Embedding model loaded successfully.")
print("Model:", EMBEDDING_MODEL_NAME)
print("Device:", embedding_model.device)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding model loaded successfully.
# Model: all-MiniLM-L6-v2
# Device: cuda:0

# %%
# Generate embeddings for RAG training documents only

rag_documents = rag_train_df["instruction"].astype(str).tolist()

print("Number of RAG training documents:", len(rag_documents))

rag_train_embeddings = embedding_model.encode(
    rag_documents,
    batch_size=64,
    convert_to_numpy=True,
    normalize_embeddings=True,
    show_progress_bar=True
).astype("float32")

print("\nEmbeddings generated successfully.")
print("Shape:", rag_train_embeddings.shape)
print("Dtype:", rag_train_embeddings.dtype)
# Out:
# Number of RAG training documents: 19708
# Batches:   0%|          | 0/308 [00:00<?, ?it/s]
# Embeddings generated successfully.
# Shape: (19708, 384)
# Dtype: float32

# %%
# !pip install faiss-gpu
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.15.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (26.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13,>=12.6 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (12.8.90)
# Requirement already satisfied: nvidia-cublas-cu12<13,>=12.6 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (12.8.4.1)
# Requirement already satisfied: nvidia-curand-cu12<11,>=10.3.7 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu) (10.3.9.90)
# Downloading faiss_gpu-1.15.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (135.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 13.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.15.1

# %%
import faiss

# Create FAISS index
embedding_dimension = rag_train_embeddings.shape[1]

index = faiss.IndexFlatIP(embedding_dimension)

# Add RAG training embeddings only
index.add(rag_train_embeddings)

print("FAISS index created successfully.")
print("Embedding dimension:", embedding_dimension)
print("Number of vectors:", index.ntotal)
# Out:
# FAISS index created successfully.
# Embedding dimension: 384
# Number of vectors: 19708

# %%
# Verify alignment between RAG training data and embeddings

print("FAISS vectors :", index.ntotal)
print("RAG train rows:", len(rag_train_df))
print("Embeddings rows:", len(rag_train_embeddings))

assert index.ntotal == len(rag_train_df)
assert len(rag_train_embeddings) == len(rag_train_df)

print("\nAlignment check passed.")
print("Each FAISS vector corresponds to the same row in rag_train_df.")
# Out:
# FAISS vectors : 19708
# RAG train rows: 19708
# Embeddings rows: 19708
#
# Alignment check passed.
# Each FAISS vector corresponds to the same row in rag_train_df.

# %%
# RAG retrieval function

def retrieve_response(query, top_k=3):
    """
    Retrieve the most relevant responses from the RAG training set.
    """

    # Encode query
    query_embedding = embedding_model.encode(
        [query],
        convert_to_numpy=True,
        normalize_embeddings=True,
        show_progress_bar=False
    ).astype("float32")

    # Search FAISS
    scores, indices = index.search(query_embedding, top_k)

    results = []

    for score, idx in zip(scores[0], indices[0]):
        results.append({
            "score": float(score),
            "instruction": rag_train_df.iloc[idx]["instruction"],
            "category": rag_train_df.iloc[idx]["category"],
            "intent": rag_train_df.iloc[idx]["intent"],
            "response": rag_train_df.iloc[idx]["response"]
        })

    return results

print("Retrieval function created successfully.")
# Out:
# Retrieval function created successfully.

# %%
# Test retrieval with a single query

query = "I want to cancel my order"

results = retrieve_response(query, top_k=3)

print("=" * 100)
print("QUERY:")
print(query)

for rank, result in enumerate(results, start=1):
    print("\n" + "-" * 100)
    print("Rank    :", rank)
    print("Score   :", round(result["score"], 4))
    print("Intent  :", result["intent"])
    print("Category:", result["category"])
    print("Text    :", result["instruction"])
    print("Response:", result["response"][:300], "...")
# Out:
# ====================================================================================================
# QUERY:
# I want to cancel my order
#
# ----------------------------------------------------------------------------------------------------
# Rank    : 1
# Score   : 0.891
# Intent  : cancel_order
# Category: ORDER
# Text    : canceling order
# Response: I pick up what you're putting down, your need to cancel your order. Let's make this process as smooth as possible. Here's what you need to do:
#
# 1. Log in to your {{Online Company Portal Info}}.
# 2. Navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section.
# 3. Locate the ...
#
# ----------------------------------------------------------------------------------------------------
# Rank    : 2
# Score   : 0.8757
# Intent  : cancel_order
# Category: ORDER
# Text    : I bought some product, I want to cancel order {{Order Number}}
# Response: I've come to understand that you've made a purchase and now you wish to cancel the order with the order number {{Order Number}}. Our cancellations team is here to help you with that. To proceed with the cancellation, you can follow these steps:
#
# 1. Access Your Account: Log in to your {{Online Compan ...
#
# ----------------------------------------------------------------------------------------------------
# Rank    : 3
# Score   : 0.8634
# Intent  : cancel_order
# Category: ORDER
# Text    : I would like to cancel purchase {{Order Number}}, I need help
# Response: I've picked up that you would like to cancel your purchase with the order number {{Order Number}} and that you need assistance. I'm here to help guide you through the cancellation process.
#
# To cancel your purchase, please follow these steps:
#
# 1. Sign into your {{Online Company Portal Info}} using yo ...

# %%
# Evaluate RAG retrieval on the leakage-free evaluation set

def evaluate_retrieval(eval_df, top_k=5):
    hits_at_1 = 0
    hits_at_3 = 0
    hits_at_5 = 0

    total = len(eval_df)

    for _, row in eval_df.iterrows():
        query = row["instruction"]
        true_intent = row["intent"]

        # Encode evaluation query
        query_embedding = embedding_model.encode(
            [query],
            convert_to_numpy=True,
            normalize_embeddings=True,
            show_progress_bar=False
        ).astype("float32")

        # Retrieve from RAG TRAIN index only
        scores, indices = index.search(query_embedding, top_k)

        retrieved_intents = [
            rag_train_df.iloc[idx]["intent"]
            for idx in indices[0]
        ]

        if true_intent == retrieved_intents[0]:
            hits_at_1 += 1

        if true_intent in retrieved_intents[:3]:
            hits_at_3 += 1

        if true_intent in retrieved_intents[:5]:
            hits_at_5 += 1

    return {
        "Recall@1": hits_at_1 / total,
        "Recall@3": hits_at_3 / total,
        "Recall@5": hits_at_5 / total
    }


retrieval_results = evaluate_retrieval(
    rag_eval_df,
    top_k=5
)

print("RAG Retrieval Evaluation")
print("=" * 60)
print("Evaluation samples:", len(rag_eval_df))

for metric, value in retrieval_results.items():
    print(f"{metric}: {value:.4f}")
# Out:
# RAG Retrieval Evaluation
# ============================================================
# Evaluation samples: 4927
# Recall@1: 0.9901
# Recall@3: 0.9976
# Recall@5: 0.9984

# %%
# Analyze cases where the top-1 retrieved intent is incorrect

errors = []

for _, row in rag_eval_df.iterrows():
    query = row["instruction"]
    true_intent = row["intent"]

    # Encode query
    query_embedding = embedding_model.encode(
        [query],
        convert_to_numpy=True,
        normalize_embeddings=True,
        show_progress_bar=False
    ).astype("float32")

    # Retrieve top 5
    scores, indices = index.search(query_embedding, 5)

    retrieved_intents = [
        rag_train_df.iloc[idx]["intent"]
        for idx in indices[0]
    ]

    top1_intent = retrieved_intents[0]

    if top1_intent != true_intent:
        errors.append({
            "query": query,
            "true_intent": true_intent,
            "top1_intent": top1_intent,
            "top1_score": float(scores[0][0]),
            "top3_intents": retrieved_intents[:3]
        })

print("Recall@1 Error Analysis")
print("=" * 70)
print("Total evaluation samples:", len(rag_eval_df))
print("Top-1 errors:", len(errors))
print(
    "Observed Recall@1:",
    round(1 - len(errors) / len(rag_eval_df), 4)
)

print("\nFirst 20 errors:")
for i, error in enumerate(errors[:20], start=1):
    print("\n" + "-" * 70)
    print("Error", i)
    print("Query       :", error["query"])
    print("True intent :", error["true_intent"])
    print("Top-1 intent:", error["top1_intent"])
    print("Top-1 score :", round(error["top1_score"], 4))
    print("Top-3       :", error["top3_intents"])
# Out:
# Recall@1 Error Analysis
# ======================================================================
# Total evaluation samples: 4927
# Top-1 errors: 49
# Observed Recall@1: 0.9901
#
# First 20 errors:
#
# ----------------------------------------------------------------------
# Error 1
# Query       : i try to sap some items of order {{Order Number}}
# True intent : change_order
# Top-1 intent: track_order
# Top-1 score : 0.7101
# Top-3       : ['track_order', 'change_order', 'change_order']
#
# ----------------------------------------------------------------------
# Error 2
# Query       : help creating account
# True intent : registration_problems
# Top-1 intent: create_account
# Top-1 score : 0.9145
# Top-3       : ['create_account', 'registration_problems', 'registration_problems']
#
# ----------------------------------------------------------------------
# Error 3
# Query       : I lost bill #85632, could you find it for me?
# True intent : check_invoice
# Top-1 intent: get_invoice
# Top-1 score : 0.9226
# Top-3       : ['get_invoice', 'get_invoice', 'check_invoice']
#
# ----------------------------------------------------------------------
# Error 4
# Query       : how to correct roder {{Order Number}}
# True intent : change_order
# Top-1 intent: cancel_order
# Top-1 score : 0.8289
# Top-3       : ['cancel_order', 'change_order', 'change_order']
#
# ----------------------------------------------------------------------
# Error 5
# Query       : I need assistance to look for the invoice #00108
# True intent : check_invoice
# Top-1 intent: get_invoice
# Top-1 score : 0.9643
# Top-3       : ['get_invoice', 'check_invoice', 'check_invoice']
#
# ----------------------------------------------------------------------
# Error 6
# Query       : open a freemium acocunt
# True intent : create_account
# Top-1 intent: switch_account
# Top-1 score : 0.8104
# Top-3       : ['switch_account', 'create_account', 'switch_account']
#
# ----------------------------------------------------------------------
# Error 7
# Query       : i have to get my invoicxes from {{Person Name}}
# True intent : get_invoice
# Top-1 intent: check_invoice
# Top-1 score : 0.7942
# Top-3       : ['check_invoice', 'get_invoice', 'get_invoice']
#
# ----------------------------------------------------------------------
# Error 8
# Query       : I have to inform of na issue with signup
# True intent : registration_problems
# Top-1 intent: contact_human_agent
# Top-1 score : 0.7047
# Top-3       : ['contact_human_agent', 'registration_problems', 'registration_problems']
#
# ----------------------------------------------------------------------
# Error 9
# Query       : I don't know what to do to check my inovice #00108
# True intent : check_invoice
# Top-1 intent: get_invoice
# Top-1 score : 0.7735
# Top-3       : ['get_invoice', 'check_invoice', 'check_invoice']
#
# ----------------------------------------------------------------------
# Error 10
# Query       : clsoe freemium account
# True intent : delete_account
# Top-1 intent: switch_account
# Top-1 score : 0.7946
# Top-3       : ['switch_account', 'create_account', 'delete_account']
#
# ----------------------------------------------------------------------
# Error 11
# Query       : get invoice from nine months ago
# True intent : get_invoice
# Top-1 intent: check_invoice
# Top-1 score : 0.8972
# Top-3       : ['check_invoice', 'get_invoice', 'get_invoice']
#
# ----------------------------------------------------------------------
# Error 12
# Query       : how can i tfack purchase {{Order Number}}
# True intent : track_order
# Top-1 intent: cancel_order
# Top-1 score : 0.8466
# Top-3       : ['cancel_order', 'cancel_order', 'cancel_order']
#
# ----------------------------------------------------------------------
# Error 13
# Query       : check invoices from two purchases ago
# True intent : check_invoice
# Top-1 intent: get_invoice
# Top-1 score : 0.8892
# Top-3       : ['get_invoice', 'check_invoice', 'check_invoice']
#
# ----------------------------------------------------------------------
# Error 14
# Query       : want help to get the invokces from {{Person Name}}
# True intent : get_invoice
# Top-1 intent: check_invoice
# Top-1 score : 0.8652
# Top-3       : ['check_invoice', 'check_invoice', 'get_invoice']
#
# ----------------------------------------------------------------------
# Error 15
# Query       : help me creting a {{Account Type}} account
# True intent : create_account
# Top-1 intent: switch_account
# Top-1 score : 0.9016
# Top-3       : ['switch_account', 'switch_account', 'switch_account']
#
# ----------------------------------------------------------------------
# Error 16
# Query       : another {{Account Type}} acconut
# True intent : create_account
# Top-1 intent: switch_account
# Top-1 score : 0.9069
# Top-3       : ['switch_account', 'switch_account', 'switch_account']
#
# ----------------------------------------------------------------------
# Error 17
# Query       : contactingassistant
# True intent : contact_human_agent
# Top-1 intent: contact_customer_service
# Top-1 score : 0.6825
# Top-3       : ['contact_customer_service', 'contact_human_agent', 'contact_human_agent']
#
# ----------------------------------------------------------------------
# Error 18
# Query       : I do not know what to do to change to another user profile
# True intent : switch_account
# Top-1 intent: edit_account
# Top-1 score : 0.7715
# Top-3       : ['edit_account', 'edit_account', 'switch_account']
#
# ----------------------------------------------------------------------
# Error 19
# Query       : I have an error entering another hsipping address
# True intent : set_up_shipping_address
# Top-1 intent: change_shipping_address
# Top-1 score : 0.6139
# Top-3       : ['change_shipping_address', 'change_shipping_address', 'change_shipping_address']
#
# ----------------------------------------------------------------------
# Error 20
# Query       : help me chsnge the delivery address
# True intent : change_shipping_address
# Top-1 intent: set_up_shipping_address
# Top-1 score : 0.8922
# Top-3       : ['set_up_shipping_address', 'set_up_shipping_address', 'set_up_shipping_address']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression


char_vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(2, 4))
X_train_vec = char_vectorizer.fit_transform(rag_train_df["instruction"])


char_clf = LogisticRegression(max_iter=1000)
char_clf.fit(X_train_vec, rag_train_df["intent"])

print("Intent Classifier trained successfully!")
# Out:
# Intent Classifier trained successfully!

# %%
 #Test the trained Intent Classifier on new queries

test_queries = [
    "I want to cancel my order",
    "What payment methods do you accept?",
    "Where can I track my order?",
    "I want a refund for my purchase",
    "I forgot my password"
]

query_features = char_vectorizer.transform(test_queries)

predicted_intents = char_clf.predict(query_features)

print("Intent Classifier Inference Test")
print("=" * 70)

for query, intent in zip(test_queries, predicted_intents):
    print("Query :", query)
    print("Intent:", intent)
    print("-" * 70)
# Out:
# Intent Classifier Inference Test
# ======================================================================
# Query : I want to cancel my order
# Intent: cancel_order
# ----------------------------------------------------------------------
# Query : What payment methods do you accept?
# Intent: check_payment_methods
# ----------------------------------------------------------------------
# Query : Where can I track my order?
# Intent: track_order
# ----------------------------------------------------------------------
# Query : I want a refund for my purchase
# Intent: get_refund
# ----------------------------------------------------------------------
# Query : I forgot my password
# Intent: recover_password
# ----------------------------------------------------------------------

# %%
# Complete RAG Pipeline

def rag_pipeline(query, top_k=3):
    # Predict intent
    query_features = char_vectorizer.transform([query])
    predicted_intent = char_clf.predict(query_features)[0]

    # Retrieve similar examples
    results = retrieve_response(query, top_k=top_k)

    return {
        "query": query,
        "predicted_intent": predicted_intent,
        "retrieved_results": results
    }


print("RAG pipeline created successfully!")
# Out:
# RAG pipeline created successfully!

# %%
# Test the complete RAG pipeline

test_queries = [
    "I want to cancel my order",
    "How can I get a refund?",
    "Where is my package?",
    "I forgot my password",
    "What payment methods can I use?"
]

for query in test_queries:
    result = rag_pipeline(query, top_k=3)

    print("=" * 100)
    print("Query:", result["query"])
    print("Predicted Intent:", result["predicted_intent"])

    print("\nRetrieved Results:")

    for rank, item in enumerate(result["retrieved_results"], start=1):
        print(f"\nRank {rank}")
        print("Score   :", round(item["score"], 4))
        print("Intent  :", item["intent"])
        print("Category:", item["category"])
        print("Response:", item["response"])
# Out:
# ====================================================================================================
# Query: I want to cancel my order
# Predicted Intent: cancel_order
#
# Retrieved Results:
#
# Rank 1
# Score   : 0.891
# Intent  : cancel_order
# Category: ORDER
# Response: I pick up what you're putting down, your need to cancel your order. Let's make this process as smooth as possible. Here's what you need to do:
#
# 1. Log in to your {{Online Company Portal Info}}.
# 2. Navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section.
# 3. Locate the order you want to cancel.
# 4. Look for the option labeled '{{Online Order Interaction}}' and click on it.
# 5. Follow any additional prompts or steps to confirm the cancellation.
#
# If you encounter any difficulties or have further questions, our dedicated team is available during {{Customer Support Hours}} at {{Customer Support Phone Number}} or through the Live Chat feature on our {{Website URL}}. We're here to assist you every step of the way. Your satisfaction is our top priority.
#
# Rank 2
# Score   : 0.8757
# Intent  : cancel_order
# Category: ORDER
# Response: I've come to understand that you've made a purchase and now you wish to cancel the order with the order number {{Order Number}}. Our cancellations team is here to help you with that. To proceed with the cancellation, you can follow these steps:
#
# 1. Access Your Account: Log in to your {{Online Company Portal Info}} using your credentials.
# 2. Locate Your Orders: Once you're logged in, navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section.
# 3. Find the Specific Purchase: Look for the order number {{Order Number}} within the order history and click on it.
# 4. Initiate the Cancellation: You should see an option labeled '{{Online Order Interaction}}' associated with the purchase. Please select this option.
# 5. Complete the Process: The system may require additional information or confirmation to finalize the cancellation. Please provide the necessary details as instructed.
#
# If you encounter any difficulties or have any questions, our dedicated team is available to assist you. You can reach us during {{Customer Support Hours}} at {{Customer Support Phone Number}} or use the Live Chat feature on our {{Website URL}}. We value your satisfaction and are committed to resolving any concerns you may have.
#
# Rank 3
# Score   : 0.8634
# Intent  : cancel_order
# Category: ORDER
# Response: I've picked up that you would like to cancel your purchase with the order number {{Order Number}} and that you need assistance. I'm here to help guide you through the cancellation process.
#
# To cancel your purchase, please follow these steps:
#
# 1. Sign into your {{Online Company Portal Info}} using your credentials.
# 2. Navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section of your account.
# 3. Locate the purchase with the order number {{Order Number}}.
# 4. Look for the option labeled '{{Online Order Interaction}}' associated with your purchase and click on it.
# 5. You may be asked to provide some additional information or confirm the cancellation. Please follow the instructions on the screen.
#
# If you encounter any issues or have any further questions, our dedicated customer support team is available to assist you. You can reach us during {{Customer Support Hours}} at {{Customer Support Phone Number}} or through our Live Chat feature on our {{Website URL}}.
#
# We appreciate your understanding and we're here to ensure a seamless cancellation process for you.
# ====================================================================================================
# Query: How can I get a refund?
# Predicted Intent: get_refund
#
# Retrieved Results:
#
# Rank 1
# Score   : 0.9928
# Intent  : get_refund
# Category: REFUND
# Response: I see your desire to obtain a refund. Rest assured, I'm here to guide you through the process and ensure your concerns are addressed. To initiate a refund, the first step is to gather all the relevant information regarding your purchase, such as the order number, date of purchase, and the reason for seeking a refund. Armed with these details, you can reach out to our dedicated customer support team either by phone at {{Customer Support Phone Number}} or through the Live Chat on our website at {{Website URL}}. They will connect you with the appropriate department who can assist you in processing your refund request. Remember, we prioritize your satisfaction and are committed to ensuring a smooth refund experience for you.
#
# Rank 2
# Score   : 0.9341
# Intent  : get_refund
# Category: REFUND
# Response: I realized, you're uncertain about the process of obtaining a refund. Rest assured, I'm here to guide you through it. To initiate a refund request, you typically need to follow a few steps. First, gather any relevant documentation, such as proof of purchase or order details. Then, reach out to the appropriate department or customer support team to inquire about their specific refund policies and procedures. They will guide you on the necessary steps to complete the process. Additionally, if you made the purchase online, you may be able to request a refund through the website or app directly. Remember, I'm here to support you every step of the way, so if you have any further questions or if there's anything else I can assist you with, please feel free to let me know.
#
# Rank 3
# Score   : 0.9234
# Intent  : get_refund
# Category: REFUND
# Response: I've got that you're looking for guidance on how to obtain refunds, and I'm here to assist you. To initiate the refund process, it's important to follow specific steps. First, I recommend reaching out to the customer support team by {{Live Chat Support}} to explain the reason for your request and provide any necessary documentation. They will guide you through the necessary procedures and inform you about the required details, such as the refund policy, timeframes, and any additional steps you may need to take. It's important to note that the refund process may vary depending on the product or service you purchased and the refund policy of the company. By following these steps and communicating with the customer support team, you can ensure a smooth and efficient refund experience.
# ====================================================================================================
# Query: Where is my package?
# Predicted Intent: delivery_period
#
# Retrieved Results:
#
# Rank 1
# Score   : 0.7574
# Intent  : delivery_period
# Category: DELIVERY
# Response: I understand your frustration and eagerness to track your package. To provide you with the most accurate information about your delivery, could you please provide me with the {{Tracking Number}} or {{Order Number}}? This will enable me to assist you in locating the estimated arrival time. We appreciate your patience and understanding.
#
# Rank 2
# Score   : 0.7517
# Intent  : delivery_period
# Category: DELIVERY
# Response: We understand your eagerness to track the arrival of your package. To provide you with the most accurate information, could you please provide us with the {{Tracking Number}} or {{Order Number}}? With that, we will be able to check the estimated delivery date for your package. We appreciate your cooperation and patience in this matter.
#
# Rank 3
# Score   : 0.726
# Intent  : delivery_period
# Category: DELIVERY
# Response: We understand your eagerness to track the progress and estimated arrival time of your package. To check the delivery status, you can visit our website and go to the "Track Order" or "Order Status" section. There, you'll be prompted to enter your {{Order Number}} or {{Tracking Number}} to retrieve the latest updates on the whereabouts of your package. If you encounter any difficulties while tracking your order, our dedicated customer support team is available around the clock to provide further assistance. Rest assured, we're committed to ensuring a seamless and transparent delivery experience for you.
# ====================================================================================================
# Query: I forgot my password
# Predicted Intent: recover_password
#
# Retrieved Results:
#
# Rank 1
# Score   : 0.8238
# Intent  : recover_password
# Category: ACCOUNT
# Response: Oh, I completely understand how frustrating it can be to forget your account password. Don't worry, I'm here to assist you in the process of resetting it so you can regain access to your account. Here's what you can do:
#
# 1. First and foremost, visit our login page at "{{Login Page URL}}" to initiate the password reset process.
# 2. Look for the option that says "{{Forgot Password}}" and click on it.
# 3. You will be prompted to enter the email address associated with your account. Please provide the correct email address to proceed.
# 4. Once you've entered your email address, an email will be sent to you shortly with instructions on how to reset your password. Please check your inbox, as well as your spam or junk folder, just in case.
# 5. Follow the instructions in the email to create a new password. Make sure to choose a strong and unique password to enhance the security of your account.
# 6. After resetting your password, go back to the login page and use your new password to access your account.
#
# If you encounter any difficulties during the process or have any additional questions, please feel free to reach out to me. I'm here to make sure your experience is seamless and you regain access to your account as soon as possible. Stay confident, you'll have access to your account in no time!"
#
# Rank 2
# Score   : 0.8205
# Intent  : recover_password
# Category: ACCOUNT
# Response: Definitely! I understand your predicament of forgetting your user password and the urgency to reset it. No worries, my friend, I'm here to lend a helping hand!
#
# To reset your password and regain access to your user account, follow these simple steps:
#
# 1. Head over to our platform's login page by navigating to "{{Login Page URL}}".
# 2. Look for the option labeled "{{Forgot Password}}" and click on it. It's like unraveling the secret pathway to a treasure chest!
# 3. On the password reset page, provide the email address associated with your user account.
# 4. Now, here comes the exciting part! You'll receive a comprehensive email shortly, containing detailed instructions on how to reset your password securely.
# 5. Don't forget to check your spam or junk folder, just in case that mischief-maker, the spam filter, decided to play a prank on you.
#
# Please ensure that you create a strong password that combines uppercase and lowercase letters, numbers, and special characters. This will help protect your account from any attempts of unauthorized access.
#
# Remember, if you encounter any issues or have further questions during the password reset process, I'm here 24/7 to assist you! Just reach out and together, we'll unlock the door to your user account.
#
# Rank 3
# Score   : 0.8003
# Intent  : recover_password
# Category: ACCOUNT
# Response: Sure! I understand the frustration of losing your password and the urgency to regain access to your account. Let's work together to recover it:
#
# 1. Visit our "{{Login Page URL}}" and look for the option labeled "{{Forgot Password}}" or "{{Reset Password}}".
# 2. Click on the option and provide the necessary information such as your email address or username.
# 3. An email will be sent to you shortly with further instructions on how to reset your password. Please check your inbox, spam, or junk folders in case the email gets redirected.
# 4. Follow the instructions provided in the email to create a new, secure password for your account.
# 5. Once you've successfully reset your password, you should be able to log in using your new credentials.
#
# If you encounter any difficulties or need additional assistance, don't hesitate to reach out to our dedicated support team. We're here to guide you every step of the way and ensure you regain access to your account smoothly.
# ====================================================================================================
# Query: What payment methods can I use?
# Predicted Intent: check_payment_methods
#
# Retrieved Results:
#
# Rank 1
# Score   : 0.9046
# Intent  : check_payment_methods
# Category: PAYMENT
# Response: I'm fully aware of your need to explore the payment methods we accept. Our goal is to provide you with a seamless and convenient payment experience. Here are the various payment methods you can choose from:
#
# - **Credit/Debit Card:** You can use major credit or debit cards like Visa, Mastercard, and American Express.
# - **PayPal:** We accept payments through PayPal, a secure and widely recognized online payment system.
# - **Bank Transfer:** You can make payments directly from your bank account through bank transfer.
# - **Mobile Payments:** We also support mobile payment options like Apple Pay, Google Pay, and Samsung Pay.
# - **E-Wallets:** You have the option to pay using popular e-wallets like Alipay, WeChat Pay, and Paytm.
#
# These are just a few of the payment methods we offer. If you need any further assistance or have more questions, feel free to let me know. We're here to assist you every step of the way!
#
# Rank 2
# Score   : 0.876
# Intent  : check_payment_methods
# Category: PAYMENT
# Response: Assuredly! I'm here to assist you in discovering the payment methods we accept. At our company, we offer a diverse range of convenient payment options to cater to your needs. Our accepted payment methods include:
#
# - Credit/Debit Cards: We accept major cards like Visa, Mastercard, and American Express, enabling swift and secure transactions.
# - PayPal: A widely recognized online payment platform known for its secure and seamless transactions.
# - Bank Transfer: You can make direct payments from your bank account to complete your purchase.
# - Apple Pay: For Apple users, this method allows for quick and hassle-free payments through your Apple device.
# - Google Pay: Utilize Google's payment system for a fast and convenient checkout experience.
#
# These are some of the most popular and widely accepted options we offer. If you have any specific questions or would like more information about any of these methods, please feel free to let me know. I'm here to help you make an informed decision and ensure a smooth payment process.
#
# Rank 3
# Score   : 0.8745
# Intent  : check_payment_methods
# Category: PAYMENT
# Response: Thank you for your inquiry! I'm here to provide you with the information you're looking for. Our platform supports a variety of payment methods to cater to your preferences. Here are the accepted payment options:
#
# - **Credit/Debit Cards:** You can securely use major credit and debit cards such as Visa, Mastercard, and American Express.
#
# - **PayPal:** We offer the convenience of PayPal for online payments, ensuring a secure and seamless transaction process.
#
# - **Bank Transfers:** Direct bank transfers are accepted, allowing you to make payments directly from your bank account.
#
# - **Apple Pay:** For Apple users, we support Apple Pay, making payment quick and easy with your Apple devices.
#
# - **Google Pay:** Google Pay is also available as a payment option, enabling a smooth checkout experience for Google users.
#
# If you have any further questions or require more details about any of these payment methods, feel free to let me know. I'm here to assist you every step of the way!

# %%
# RAG pipeline with retrieval confidence threshold

def rag_pipeline_with_threshold(query, top_k=3, threshold=0.45):

    # Intent prediction
    query_features = char_vectorizer.transform([query])
    predicted_intent = char_clf.predict(query_features)[0]

    # Retrieval
    results = retrieve_response(query, top_k=top_k)

    # Check retrieval confidence
    best_score = results[0]["score"]

    if best_score < threshold:
        return {
            "query": query,
            "predicted_intent": predicted_intent,
            "response": "Sorry, I could not find a sufficiently relevant answer.",
            "confidence": best_score,
            "retrieved_results": results
        }

    # Use the most relevant retrieved response
    best_result = results[0]

    return {
        "query": query,
        "predicted_intent": predicted_intent,
        "response": best_result["response"],
        "confidence": best_score,
        "retrieved_results": results
    }


print("Threshold-based RAG pipeline created!")
# Out:
# Threshold-based RAG pipeline created!

# %%
# Final RAG inference test

query = "I want to cancel my order"

result = rag_pipeline_with_threshold(query)

print("=" * 100)
print("USER QUERY")
print(result["query"])

print("\nPREDICTED INTENT")
print(result["predicted_intent"])

print("\nRETRIEVAL CONFIDENCE")
print(round(result["confidence"], 4))

print("\nFINAL RESPONSE")
print(result["response"])
# Out:
# ====================================================================================================
# USER QUERY
# I want to cancel my order
#
# PREDICTED INTENT
# cancel_order
#
# RETRIEVAL CONFIDENCE
# 0.891
#
# FINAL RESPONSE
# I pick up what you're putting down, your need to cancel your order. Let's make this process as smooth as possible. Here's what you need to do:
#
# 1. Log in to your {{Online Company Portal Info}}.
# 2. Navigate to the '{{Online Order Interaction}}' or '{{Online Order Interaction}}' section.
# 3. Locate the order you want to cancel.
# 4. Look for the option labeled '{{Online Order Interaction}}' and click on it.
# 5. Follow any additional prompts or steps to confirm the cancellation.
#
# If you encounter any difficulties or have further questions, our dedicated team is available during {{Customer Support Hours}} at {{Customer Support Phone Number}} or through the Live Chat feature on our {{Website URL}}. We're here to assist you every step of the way. Your satisfaction is our top priority.

# %%
# Save RAG artifacts

import os
import joblib
import pickle

os.makedirs("models", exist_ok=True)

# Save intent classifier and vectorizer
joblib.dump(
    char_vectorizer,
    "models/rag_intent_vectorizer.pkl"
)

joblib.dump(
    char_clf,
    "models/rag_intent_classifier.pkl"
)

# Save FAISS index
faiss.write_index(
    index,
    "models/rag_faiss.index"
)

# Save RAG dataframe
rag_train_df.to_pickle(
    "models/rag_documents.pkl"
)

print("All RAG artifacts saved successfully!")
# Out:
# All RAG artifacts saved successfully!
